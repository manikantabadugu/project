# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter

# %%
df=pd.read_csv("dataset.csv")
df
# Out:
#      Unnamed: 0                                                url  \
# 0             0  https://www.goodreads.com/book/show/2657.To_Ki...
# 1             1  https://www.goodreads.com/book/show/40961427-1984
# 2             2  https://www.goodreads.com/book/show/3.Harry_Po...
# 3             3  https://www.goodreads.com/book/show/4671.The_G...
# 4             4  https://www.goodreads.com/book/show/170448.Ani...
# ..          ...                                                ...
# 609         609  https://www.goodreads.com/book/show/14358.A_Ri...
# 610         610  https://www.goodreads.com/book/show/39242.The_...
# 611         611  https://www.goodreads.com/book/show/64105.The_...
# 612         612  https://www.goodreads.com/book/show/776573.Rid...
# 613         613  https://www.goodreads.com/book/show/244261.The...
#
#                                      title                 author  \
# 0                    To Kill a Mockingbird             Harper Lee
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# url                        0
# title                      0
# author                     0
# num_reviews                0
# num_ratings                0
# avg_rating                 0
# num_pages                  0
# original_publish_year      0
# series                     0
# genres                     0
# awards                     0
# places                   300
# awards_count               0
# dtype: int64

# %%
df2=df['places']
df3=df['url']

# %%
page = requests.get("https://www.goodreads.com/book/show/244261.The_Street_of_Crocodiles")
print(page)
# Out:
# <Response [200]>

# %%
#def insert_country(urls):
urls='https://www.goodreads.com/book/show/13079982-fahrenheit-451'
def inserting(urls):
    page = requests.get(urls)
    soup = BeautifulSoup(page.content, "html.parser")
#info= soup.find_all('div', class_= "buttons")
    names=soup.find_all('div',class_="infoBoxRowItem")
    place=[]
    for i in names:
          place.append(i.text)
    for i in range(len(place)):
            place[i]=place[i].strip()
    
    return  place
#urls='https://www.goodreads.com/book/show/13079982-fahrenheit-451'
#insert_country(urls)

# %%
urls='https://www.goodreads.com/book/show/13079982-fahrenheit-451'
def inserting(urls):
    page = requests.get(urls)
    soup = BeautifulSoup(page.content, "html.parser")
#info= soup.find_all('div', class_= "buttons")
    names=soup.find_all('div',class_="infoBoxRowItem")
    place=[]
    for i in names:
          place.append(i.text)
    for i in range(len(place)):
               place[i]=place[i].strip()
    return

# %%
place
# Out:
# ['Fahrenheit 451',
#  'B0064CPN7I',
#  'English',
#  'https://raybradbury.com/work/',
#  'Guy Montag, Norman Corwin, Clarisse McClellan, Mildred Montag, Captain Beatty...more, Professor Faber...less',
#  'Prometheus Hall of Fame Award (1984), Geffen Award for Best Translated SF Book (2002), California Book Award for Fiction (Silver) (1953), Retro Hugo Award for Best Novel (2004)',
#  'All Editions\n\n | \n\nAdd a New Edition\n\n | \n\nCombine']

# %%
for i in range(len(df2)):
    x= 'NaN'
    if df2[i]==' ':
            k=df3[i]
            print(page)
            m= inserting(k)
            origin=page[5]
            df2[i]=df2[i].append(origin) 
            print(df2)

print(df2)
# Out:
# 0       United States
# 1      United Kingdom
# 2      United Kingdom
# 3       United States
# 4                 NaN
#             ...
# 609     United States
# 610     United States
# 611               NaN
# 612    United Kingdom
# 613               NaN
# Name: places, Length: 614, dtype: object

# %%
x = [x, Nan]
if x==:
    print(x)
